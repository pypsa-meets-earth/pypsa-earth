# %%
import pandas as pd
import geopandas as gpd
import numpy as np
from geopy.geocoders import Nominatim

# %%
ports_raw = pd.read_csv('data/ports_volume.csv', sep=';', names=['year', 'federal_state', 'municipality', 'port', 'freight_volume_t', 'gross_container_throughput'], skiprows=1, dtype={'freight_volume_t':'string', 'gross_container_throughput':'string'})
ports = ports_raw

#Port part id
ports['port_part_id'] = ports.port + ' in ' + ports.municipality

#Rename not classified ports
ports.loc[ports.port == 'Não Classificado', 'port'] = ports.loc[ports.port == 'Não Classificado', 'municipality']

#Replace isolated installation string
ports['port'] = ports.port.str.replace(' (Instalação Isolada)', '', regex=False)

#Insert country column
ports['country'] = 'BR'

#Filter for active ports using assumption that data must haven been collected since 2020
ports = ports.loc[ports.port.isin(ports.loc[ports.year > 2020, 'port'])]

#Cast freight and container column to float
ports.loc[ports.freight_volume_t == ',', 'freight_volume_t'] = '0'
ports['freight_volume_t'] = ports.freight_volume_t.str.replace('.', '').str.replace(',', '.').astype(float)
ports['gross_container_throughput'] = ports.gross_container_throughput.str.replace('.', '').str.replace(',', '.').astype(int)

#Groupby port and calculate mean freight
ports = ports.groupby('port_part_id').agg({
                                       'country':'first',
                                       'federal_state':'first',
                                       'municipality':'first',
                                       'port':'first',
                                       'year':'mean',
                                       'freight_volume_t':'mean',
                                       'gross_container_throughput':'mean'

})
ports = ports.groupby('port').agg({
                                       'country':'first',
                                       'federal_state':'first',
                                       'municipality':'first',
                                       'freight_volume_t':'sum',
                                       'gross_container_throughput':'sum'

})

#Calculate ports' energy share
ports['fraction'] = (ports.freight_volume_t / ports.freight_volume_t.sum()
                    + ports.gross_container_throughput / ports.gross_container_throughput.sum()) / 2

ports.sort_values(by='fraction', ascending=False)
# Out:
# /tmp/ipykernel_3243259/2737516551.py:21: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   ports['freight_volume_t'] = ports.freight_volume_t.str.replace('.', '').str.replace(',', '.').astype(float)
# /tmp/ipykernel_3243259/2737516551.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   ports['gross_container_throughput'] = ports.gross_container_throughput.str.replace('.', '').str.replace(',', '.').astype(int)
#                           country federal_state         municipality  \
# port
# Santos                         BR            SP              Cubatão
# Itaqui                         BR            MA             São Luís
# Paranaguá - Antonina           BR            PR             Antonina
# São Francisco do Sul           BR            SC               Itapoá
# Itajaí                         BR            SC               Itajaí
# Manaus                         BR            AM          Itacoatiara
# Vitória                        BR            ES             Anchieta
# Rio de Janeiro -  Niterói      BR            RJ      Duque de Caxias
# Rio Grande                     BR            RS              Pelotas
# Itaguaí                        BR            RJ              Itaguaí
# Suape - Recife                 BR            PE              Ipojuca
# Angra dos Reis                 BR            RJ       Angra dos Reis
# Aratu - Salvador               BR            BA             Candeias
# São Sebastião                  BR            SP        São Sebastião
# Pecém - Fortaleza              BR            CE            Fortaleza
# São João da Barra              BR            RJ    São João da Barra
# Vila do Conde - Belém          BR            PA            Barcarena
# Porto Alegre                   BR            RS         Porto Alegre
# Óbidos                         BR            PA               Juruti
# Imbituba                       BR            SC             Imbituba
# Itaituba                       BR            PA             Itaituba
# Santarém                       BR            PA             Santarém
# Porto Velho                    BR            RO          Porto Velho
# Barra do Riacho                BR            ES              Aracruz
# Natal                          BR            RN              Guamaré
# Maceió                         BR            AL               Maceió
# Macapá                         BR            AP              Santana
# Corumbá                        BR            MS              Corumbá
# Ilhéus                         BR            BA             Belmonte
# Cabedelo                       BR            PB             Cabedelo
# Coari                          BR            AM                Coari
# Mossoró                        BR            RN              Mossoró
# Aracajú                        BR            SE  Barra dos Coqueiros
# Macau                          BR            RN                Macau
# Humaitá                        BR            AM              Humaitá
# Belém                          BR            PA                Belém
# São Simão                      BR            GO            São Simão
# Santana                        BR            AP              Santana
# Tomé Açu                       BR            PA                Acará
# Vitória do Xingu               BR            PA     Vitória do Xingu
# Caracaraí                      BR            RR            Caracaraí
# Almeirim                       BR            PA             Almeirim
# Ananindeua                     BR            PA           Ananindeua
# Rio de Janeiro                 BR            RJ       Rio de Janeiro
# Oriximiná                      BR            PA            Oriximiná
# Cruzeiro do Sul                BR            AC      Cruzeiro do Sul
#
#                            freight_volume_t  gross_container_throughput  \
# port
# Santos                            9918240.0                    188741.0
# Itaqui                           14349837.4                         0.0
# Paranaguá - Antonina              4177252.0                     46562.0
# São Francisco do Sul              3091317.2                     42738.0
# Itajaí                            1143580.7                     54217.0
# Manaus                            2508503.1                     38810.0
# Vitória                           7091374.6                     11105.0
# Rio de Janeiro -  Niterói         2254032.2                     32507.0
# Rio Grande                        2959034.2                     27506.0
# Itaguaí                           6476079.4                      4821.0
# Suape - Recife                    2415334.1                     25279.0
# Angra dos Reis                    6342797.2                         0.0
# Aratu - Salvador                  2974395.3                     15676.0
# São Sebastião                     4912223.5                         0.0
# Pecém - Fortaleza                 1615338.1                     19374.0
# São João da Barra                 4163396.0                         0.0
# Vila do Conde - Belém             2862525.4                      1156.0
# Porto Alegre                      1281285.9                      2092.0
# Óbidos                            1258163.0                         0.0
# Imbituba                           514497.5                      3115.0
# Itaituba                           928120.9                         0.0
# Santarém                           895917.8                        56.0
# Porto Velho                        654850.2                       659.0
# Barra do Riacho                    733255.3                         0.0
# Natal                              264886.4                      2550.0
# Maceió                             296543.7                         0.0
# Macapá                             272227.4                         0.0
# Corumbá                            172213.0                         0.0
# Ilhéus                             157189.0                         0.0
# Cabedelo                            94991.8                         0.0
# Coari                               84153.1                         0.0
# Mossoró                             78139.5                         0.0
# Aracajú                             64362.0                         0.0
# Macau                               57208.9                         0.0
# Humaitá                             44000.5                         0.0
# Belém                               33954.7                         0.0
# São Simão                           22145.6                         0.0
# Santana                              9490.8                         0.0
# Tomé Açu                             5914.6                         0.0
# Vitória do Xingu                     3022.2                         0.0
# Caracaraí                            2983.9                         0.0
# Almeirim                             2201.1                         0.0
# Ananindeua                           1861.2                         0.0
# Rio de Janeiro                         88.0                         0.0
# Oriximiná                               0.0                         0.0
# Cruzeiro do Sul                         0.0                         0.0
#
#                                fraction
# port
# Santos                     2.394254e-01
# Itaqui                     8.229163e-02
# Paranaguá - Antonina       6.898926e-02
# São Francisco do Sul       5.906326e-02
# Itajaí                     5.899595e-02
# Manaus                     5.192191e-02
# Vitória                    5.140731e-02
# Rio de Janeiro -  Niterói  4.436643e-02
# Rio Grande                 4.357249e-02
# Itaguaí                    4.180100e-02
# Suape - Recife             3.830063e-02
# Angra dos Reis             3.637387e-02
# Aratu - Salvador           3.221878e-02
# São Sebastião              2.817000e-02
# Pecém - Fortaleza          2.800168e-02
# São João da Barra          2.387571e-02
# Vila do Conde - Belém      1.753371e-02
# Porto Alegre               9.371107e-03
# Óbidos                     7.215153e-03
# Imbituba                   5.963257e-03
# Itaituba                   5.322470e-03
# Santarém                   5.191958e-03
# Porto Velho                4.392727e-03
# Barra do Riacho            4.204979e-03
# Natal                      3.985360e-03
# Maceió                     1.700581e-03
# Macapá                     1.561135e-03
# Corumbá                    9.875853e-04
# Ilhéus                     9.014275e-04
# Cabedelo                   5.447469e-04
# Coari                      4.825905e-04
# Mossoró                    4.481045e-04
# Aracajú                    3.690950e-04
# Macau                      3.280743e-04
# Humaitá                    2.523285e-04
# Belém                      1.947191e-04
# São Simão                  1.269978e-04
# Santana                    5.442664e-05
# Tomé Açu                   3.391830e-05
# Vitória do Xingu           1.733133e-05
# Caracaraí                  1.711169e-05
# Almeirim                   1.262259e-05
# Ananindeua                 1.067337e-05
# Rio de Janeiro             5.046512e-07
# Oriximiná                  0.000000e+00
# Cruzeiro do Sul            0.000000e+00

# %%
#Geolocate Ports
geolocator = Nominatim(user_agent='port_locations')

for port_id, port in ports.iterrows():
    
    loc_string = port_id + ', ' + port.federal_state
    try:
        loc = geolocator.geocode(query=loc_string, country_codes='br')
        ports.loc[port_id, 'y'] = loc.latitude
        ports.loc[port_id, 'x'] = loc.longitude
    except:
        try:
            loc = geolocator.geocode(query=loc_string, country_codes='br')
            ports.loc[port_id, 'y'] = loc.latitude
            ports.loc[port_id, 'x'] = loc.longitude
        except:
            ports.loc[port_id, 'y'] = 'not found'
            ports.loc[port_id, 'x'] = 'not found'
ports.sort_values(by='fraction', ascending=False)
# Out:
#                           country federal_state         municipality  \
# port
# Almeirim                       BR            PA             Almeirim
# Ananindeua                     BR            PA           Ananindeua
# Angra dos Reis                 BR            RJ       Angra dos Reis
# Aracajú                        BR            SE  Barra dos Coqueiros
# Aratu - Salvador               BR            BA             Candeias
# Barra do Riacho                BR            ES              Aracruz
# Belém                          BR            PA                Belém
# Cabedelo                       BR            PB             Cabedelo
# Caracaraí                      BR            RR            Caracaraí
# Coari                          BR            AM                Coari
# Corumbá                        BR            MS              Corumbá
# Cruzeiro do Sul                BR            AC      Cruzeiro do Sul
# Humaitá                        BR            AM              Humaitá
# Ilhéus                         BR            BA             Belmonte
# Imbituba                       BR            SC             Imbituba
# Itaguaí                        BR            RJ              Itaguaí
# Itaituba                       BR            PA             Itaituba
# Itajaí                         BR            SC               Itajaí
# Itaqui                         BR            MA             São Luís
# Macapá                         BR            AP              Santana
# Macau                          BR            RN                Macau
# Maceió                         BR            AL               Maceió
# Manaus                         BR            AM          Itacoatiara
# Mossoró                        BR            RN              Mossoró
# Natal                          BR            RN              Guamaré
# Oriximiná                      BR            PA            Oriximiná
# Paranaguá - Antonina           BR            PR             Antonina
# Pecém - Fortaleza              BR            CE            Fortaleza
# Porto Alegre                   BR            RS         Porto Alegre
# Porto Velho                    BR            RO          Porto Velho
# Rio Grande                     BR            RS              Pelotas
# Rio de Janeiro                 BR            RJ       Rio de Janeiro
# Rio de Janeiro -  Niterói      BR            RJ      Duque de Caxias
# Santana                        BR            AP              Santana
# Santarém                       BR            PA             Santarém
# Santos                         BR            SP              Cubatão
# Suape - Recife                 BR            PE              Ipojuca
# São Francisco do Sul           BR            SC               Itapoá
# São João da Barra              BR            RJ    São João da Barra
# São Sebastião                  BR            SP        São Sebastião
# São Simão                      BR            GO            São Simão
# Tomé Açu                       BR            PA                Acará
# Vila do Conde - Belém          BR            PA            Barcarena
# Vitória                        BR            ES             Anchieta
# Vitória do Xingu               BR            PA     Vitória do Xingu
# Óbidos                         BR            PA               Juruti
#
#                            freight_volume_t  gross_container_throughput  \
# port
# Almeirim                             2201.1                         0.0
# Ananindeua                           1861.2                         0.0
# Angra dos Reis                    6342797.2                         0.0
# Aracajú                             64362.0                         0.0
# Aratu - Salvador                  2974395.3                     15676.0
# Barra do Riacho                    733255.3                         0.0
# Belém                               33954.7                         0.0
# Cabedelo                            94991.8                         0.0
# Caracaraí                            2983.9                         0.0
# Coari                               84153.1                         0.0
# Corumbá                            172213.0                         0.0
# Cruzeiro do Sul                         0.0                         0.0
# Humaitá                             44000.5                         0.0
# Ilhéus                             157189.0                         0.0
# Imbituba                           514497.5                      3115.0
# Itaguaí                           6476079.4                      4821.0
# Itaituba                           928120.9                         0.0
# Itajaí                            1143580.7                     54217.0
# Itaqui                           14349837.4                         0.0
# Macapá                             272227.4                         0.0
# Macau                               57208.9                         0.0
# Maceió                             296543.7                         0.0
# Manaus                            2508503.1                     38810.0
# Mossoró                             78139.5                         0.0
# Natal                              264886.4                      2550.0
# Oriximiná                               0.0                         0.0
# Paranaguá - Antonina              4177252.0                     46562.0
# Pecém - Fortaleza                 1615338.1                     19374.0
# Porto Alegre                      1281285.9                      2092.0
# Porto Velho                        654850.2                       659.0
# Rio Grande                        2959034.2                     27506.0
# Rio de Janeiro                         88.0                         0.0
# Rio de Janeiro -  Niterói         2254032.2                     32507.0
# Santana                              9490.8                         0.0
# Santarém                           895917.8                        56.0
# Santos                            9918240.0                    188741.0
# Suape - Recife                    2415334.1                     25279.0
# São Francisco do Sul              3091317.2                     42738.0
# São João da Barra                 4163396.0                         0.0
# São Sebastião                     4912223.5                         0.0
# São Simão                           22145.6                         0.0
# Tomé Açu                             5914.6                         0.0
# Vila do Conde - Belém             2862525.4                      1156.0
# Vitória                           7091374.6                     11105.0
# Vitória do Xingu                     3022.2                         0.0
# Óbidos                            1258163.0                         0.0
#
#                                fraction          y          x
# port
# Almeirim                   1.262259e-05  -1.529038 -52.578811
# Ananindeua                 1.067337e-05  -1.374035 -48.401662
# Angra dos Reis             3.637387e-02 -23.006397 -44.316326
# Aracajú                    3.690950e-04 -10.916206 -37.077466
# Aratu - Salvador           3.221878e-02 -12.792619 -38.490386
# Barra do Riacho            4.204979e-03 -19.826546 -40.063682
# Belém                      1.947191e-04  -1.450560 -48.468245
# Cabedelo                   5.447469e-04  -6.973240 -34.835161
# Caracaraí                  1.711169e-05   1.827598 -61.125389
# Coari                      4.825905e-04  -4.088596 -63.143117
# Corumbá                    9.875853e-04 -19.001637 -57.653432
# Cruzeiro do Sul            0.000000e+00  -7.630796 -72.670387
# Humaitá                    2.523285e-04  -7.509940 -63.024867
# Ilhéus                     9.014275e-04 -14.792599 -39.045384
# Imbituba                   5.963257e-03 -28.241827 -48.664344
# Itaguaí                    4.180100e-02 -22.862960 -43.775322
# Itaituba                   5.322470e-03  -4.262522 -55.987814
# Itajaí                     5.899595e-02 -26.904679 -48.655298
# Itaqui                     8.229163e-02  -2.557055 -44.352347
# Macapá                     1.561135e-03   0.040153 -51.056959
# Macau                      3.280743e-04  -5.113170 -36.635068
# Maceió                     1.700581e-03  -9.647684 -35.733926
# Manaus                     5.192191e-02  -3.131633 -59.982504
# Mossoró                    4.481045e-04  -5.190433 -37.344387
# Natal                      3.985360e-03  -5.805398 -35.208090
# Oriximiná                  0.000000e+00  -1.766999 -55.868285
# Paranaguá - Antonina       6.898926e-02 -25.427117 -48.711301
# Pecém - Fortaleza          2.800168e-02  -3.604417 -38.890484
# Porto Alegre               9.371107e-03 -30.032500 -51.230377
# Porto Velho                4.392727e-03  -8.749453 -63.873544
# Rio Grande                 4.357249e-02 -32.033425 -52.099130
# Rio de Janeiro             5.046512e-07 -22.911014 -43.209373
# Rio de Janeiro -  Niterói  4.436643e-02 -22.881839 -43.063180
# Santana                    5.442664e-05  -0.030707 -51.178967
# Santarém                   5.191958e-03  -2.438489 -54.699611
# Santos                     2.394254e-01 -23.933599 -46.328640
# Suape - Recife             3.830063e-02  -8.353907 -34.956736
# São Francisco do Sul       5.906326e-02 -26.249509 -48.630809
# São João da Barra          2.387571e-02 -21.634859 -41.048708
# São Sebastião              2.817000e-02 -23.802787 -45.407053
# São Simão                  1.269978e-04 -18.993988 -50.546383
# Tomé Açu                   3.391830e-05  -2.416631 -48.152291
# Vila do Conde - Belém      1.753371e-02  -1.566629 -48.764367
# Vitória                    5.140731e-02 -20.320092 -40.337668
# Vitória do Xingu           1.733133e-05  -2.883306 -52.011489
# Óbidos                     7.215153e-03  -1.901072 -55.520812

# %%
#export port data
ports.to_csv('data/export_ports.csv')
